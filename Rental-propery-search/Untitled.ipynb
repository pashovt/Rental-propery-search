# %%
from bs4 import BeautifulSoup
import urllib.request
import csv
import requests
import folium
from folium.plugins import MarkerCluster
from geopy.geocoders import Nominatim
import random
import time

import pandas as pd
import numpy as np

# %%
# info resourse: https://propertypressonline.co.uk/2020/12/01/best-renting-websites-uk/

# websites for renting a whole property
# https://www.openrent.co.uk/

########################### Zoopla - https://www.zoopla.co.uk/to-rent/ ###########################
location = 'nottingham'
min_bed = 2 # bedrooms
max_price = 700 # pounds
min_price = 400 # pounds
zoopla_distance = [0.25, 0.5, 1, 3, 5, 10, 15, 20, 30, 40]
radius = 1 # mile
page = 1

zoopla_url = f'https://www.zoopla.co.uk/to-rent/property/{location}/?beds_min={min_bed}&page_size=25&price_frequency=per_month&price_max={max_price}&price_min={min_price}&q={location}&radius={radius}&results_sort=newest_listings&search_source=refine&pn={page}'


############################ https://www.rightmove.co.uk/property-to-rent.html ###########################

# will need location identifier probably will require a input to the home page

f'https://www.rightmove.co.uk/property-to-rent/find.html?searchType=RENT&locationIdentifier=OUTCODE%5E1752&insId=1&radius=0.0&minPrice=350&maxPrice=600&minBedrooms=0&maxBedrooms=3&displayPropertyType=houses&maxDaysSinceAdded=&sortByPriceDescending=&_includeLetAgreed=off&primaryDisplayPropertyType=&secondaryDisplayPropertyType=&oldDisplayPropertyType=&oldPrimaryDisplayPropertyType=&letType=&letFurnishType=&houseFlatShare='
f'https://www.rightmove.co.uk/property-to-rent/find.html?locationIdentifier=REGION%5E1019&maxBedrooms=3&minBedrooms=0&maxPrice=600&minPrice=350&index=24&propertyTypes=detached%2Csemi-detached%2Cterraced&primaryDisplayPropertyType=houses&includeLetAgreed=false&mustHave=&dontShow=&furnishTypes=&keywords='


############################ https://www.movebubble.com/ ###########################

########################### Gumtree - https://www.gumtree.com/property-to-rent ###########################
location = 'nottingham'
min_bed = 2
max_bed = 3
property_type = 'house'
max_price = 700 # pounds
min_price = 400 # pounds
distance_list = [1, 3, 5, 10, 15, 30, 50, 75, 100]
category= 'property-to-rent'
page = 1

dist = 1 # === radius
distances = []

gumtree_url = f'https://www.gumtree.com/search?search_category={category}&search_location={location}&q={property_type}&page={page}&distance=15&min_price={min_price}&max_price={max_price}&min_property_number_beds={min_bed}&max_property_number_beds={max_bed}'

########################### https://www.rentify.com/ ###########################

urls = ''

# websites for renting a single room from a property
# https://www.spareroom.co.uk/
# https://www.roomgo.co.uk/
# https://www.idealflatmate.co.uk/
# https://roommatesuk.com/
# https://www.speedflatmating.co.uk/


# # # # # # FIRST CHECK URLS FOR SEARCH METHODS ON THEIR STRINGS # # # # # #
# WEBSCRAPING 
# #extract webpage html, including multiple pages of the webpage
# url1 = 'https://www.iproperty.com.sg/rent/district-' + str(postal_district)+ '/hdb/?bedroom=' + str(bedroom) + '&page=' + str(j)
# headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
# page = requests.get(url1,headers= headers)
# soupysoupy = BeautifulSoup(page.text,'html.parser')



# calculator website - https://www.allagents.co.uk/calculator/mortgage-rent/
# TODO - the checker returns if it is better to buy a property or rent it
# TO CHECK for integration with the annual yield if a property is bought to confirm what returns will be expected from it
def rent_checker(house_price, morgage_required, payment_period, interest_rate, monthly_rent):
    pass 

# to accomodate for current property income to be a int of a list
def morgage_return_period(morgage, current_property_income):
    pass

# %%
# to get the total number of pages for each search
# make a function to check for the closest radius for each url and return the closest, the previous and the next

from webbot import Browser

location = 'nottingham'
category= 'property-to-rent'
property_type = 'house'
min_bed = 2 # bedrooms
max_bed = 3
max_price = 700 # pounds
min_price = 400 # pounds
radius = 1 # mile
page = 1

gumtree_url = f'https://www.gumtree.com/search?search_category={category}&search_location={location}&q={property_type}&page={page}&distance=15&min_price={min_price}&max_price={max_price}&min_property_number_beds={min_bed}&max_property_number_beds={max_bed}'


web = Browser()
web.go_to(gumtree_url)

# %%
zoopla_distance = [0.25, 0.5, 1, 3, 5, 10, 15, 20, 30, 40]
gumtree_distance = [1, 3, 5, 10, 15, 30, 50, 75, 100]

list_of_radiuses = zoopla_distance + gumtree_distance
list_of_radiuses = list(set(list_of_radiuses))
list_of_radiuses.sort()


def radius_alligner(radius, list_of_radiuses):
    """
    Find the common radius
    """ 
    pass
#     for rad in list_of_radiuses:
        
        
        
#     pass    

def rad_returner(rad, rad_list, previous=None, next_=None):
    pass


# list_of_radiuses(list_of_radiuses < 3)

x = [x<3 for x in list_of_radiuses]
x 
# for good_list in filter(lambda x: max(x)<=70, listoflists):
   # do stuff
# Out:
# [True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False]

# %% [markdown]
# ## For buy property

# %%
# Calculates the annual yield of a rented property

Annual_rental_income = 8400
Prorperty_Purchase_price= 150.000
Property_current_price = []

annual_yield = 100*Annual_rental_income/Purchase_price

if annual_yield < 7:
    print(f'Current annual yield of {annual_yield} is below the ideal return!')
else:
    print(f'The current annual yield of {annual_yield} is performining extremely well!')
